# %% [markdown]
# **College Placement Dataset**

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data=pd.read_csv('/content/placement-dataset.csv')

# %%
data
# Out:
#            city  cgpa     iq  placement
# 0      New York   6.8  123.0          1
# 1   Los Angeles   5.9  106.0          0
# 2       Chicago   NaN  121.0          0
# 3      New York   7.4  132.0          1
# 4   Los Angeles   5.8  142.0          0
# ..          ...   ...    ...        ...
# 95      Chicago   4.3  200.0          0
# 96     New York   4.4   42.0          0
# 97  Los Angeles   6.7  182.0          1
# 98      Chicago   6.3  103.0          1
# 99     New York   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
data.head()
# Out:
#           city  cgpa     iq  placement
# 0     New York   6.8  123.0          1
# 1  Los Angeles   5.9  106.0          0
# 2      Chicago   NaN  121.0          0
# 3     New York   7.4  132.0          1
# 4  Los Angeles   5.8  142.0          0

# %%
data.tail()
# Out:
#            city  cgpa     iq  placement
# 95      Chicago   4.3  200.0          0
# 96     New York   4.4   42.0          0
# 97  Los Angeles   6.7  182.0          1
# 98      Chicago   6.3  103.0          1
# 99     New York   6.2  113.0          1

# %%
data.sample()
# Out:
#            city  cgpa     iq  placement
# 76  Los Angeles   4.9  155.0          0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   city       100 non-null    object
#  1   cgpa       92 non-null     float64
#  2   iq         96 non-null     float64
#  3   placement  100 non-null    int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.2+ KB

# %%
data.describe()
# Out:
#             cgpa          iq   placement
# count  92.000000   96.000000  100.000000
# mean    5.965217  117.916667    0.460000
# std     1.164911   46.913508    0.500908
# min     3.300000    1.000000    0.000000
# 25%     5.000000   90.000000    0.000000
# 50%     6.000000  122.000000    0.000000
# 75%     6.825000  146.750000    1.000000
# max     8.500000  233.000000    1.000000

# %%
data.isnull().sum()
# Out:
# city         0
# cgpa         8
# iq           4
# placement    0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.value_counts('city')
# Out:
# city
# New York       31
# Los Angeles    30
# Chicago        27
# dtype: int64

# %%
data['city'].value_counts().plot(kind='bar',color=['#CCB974','#8172B3','#64B5CD'])
plt.grid(ls=':',c='k')
plt.xticks(rotation=360)
plt.show()

# %%
sns.histplot(x="iq", hue="placement", data=data, multiple="stack")
# Out:
# <Axes: xlabel='iq', ylabel='Count'>

# %%
figsize = (12, 1.2 * len(data['city'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(data, x='cgpa', y='city', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
plt.show()
# Out:
# <ipython-input-75-1f1cdfea3a12>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data, x='cgpa', y='city', inner='stick', palette='Dark2')

# %%
figsize = (12, 1.2 * len(data['city'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(data, x='iq', y='city', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
plt.show()
# Out:
# <ipython-input-80-d821821abb28>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data, x='iq', y='city', inner='stick', palette='Dark2')

# %%
sns.scatterplot(x = 'cgpa', y = 'iq', hue = 'city', data = data)
plt.show()

# %%
data['cgpa'].plot(kind='hist', bins=20, title='cgpa')
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.show()

# %%
data.plot(kind='scatter', x='cgpa', y='iq', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# **THE END**
